# %%
# %bookmark HOME "/home/jupyter/meta_XLM/XLM" 
# %cd -b HOME
# Out:
# (bookmark:HOME) -> /home/jupyter/meta_XLM/XLM
# /home/jupyter/meta_XLM/XLM

# %%
# %env OUTPATH=/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed
# %env exp_id=maml
# If you don't have enough RAM or swap memory, leave these three parameters to True, otherwise you may get an error like this when evaluating 
# RuntimeError: copy_if failed to synchronize: cudaErrorAssert: device-side assert triggered
# %env remove_long_sentences_train=True
# %env remove_long_sentences_valid=True
# %env remove_long_sentences_test=True
#--remove_long_sentences_train $remove_long_sentences_train --remove_long_sentences_valid $remove_long_sentences_valid --remove_long_sentences_test $remove_long_sentences_test
# Out:
# env: OUTPATH=/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed
# env: exp_id=maml
# env: remove_long_sentences_train=True
# env: remove_long_sentences_valid=True
# env: remove_long_sentences_test=True

# %%
# %env epoch_size=23118
# %env lgs=en-fr-Bafia-Bulu-MKPAMAN_AMVOE_Ewondo
# Out:
# env: epoch_size=23118
# env: lgs=en-fr-Bafia-Bulu-MKPAMAN_AMVOE_Ewondo

# %%
# limit the number of examples (-1 by default for non limitation)
# %env train_n_samples=-1
# %env valid_n_samples=-1
# %env test_n_samples=-1
#--train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples

# %env eval_bleu=true
! chmod +x src/evaluation/multi-bleu.perl
# Out:
# env: train_n_samples=-1
# env: valid_n_samples=-1
# env: test_n_samples=-1
# env: eval_bleu=true

# %%
# %env stopping_criterion=valid_fr-Bulu_mt_bleu,10
# %env validation_metrics=valid_fr-Bulu_mt_bleu
# %env reload_model=/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth,/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth

#%env ae_steps=en,fr,Bafia,Bulu,MKPAMAN_AMVOE_Ewondo
# %env ae_steps=fr,Bafia,Bulu,MKPAMAN_AMVOE_Ewondo
# %env bt_steps=Bafia-fr-Bafia,fr-Bafia-fr,Bulu-fr-Bulu,fr-Bulu-fr,MKPAMAN_AMVOE_Ewondo-fr-MKPAMAN_AMVOE_Ewondo,fr-MKPAMAN_AMVOE_Ewondo-fr


# %env train_n_samples=-1
# %env valid_n_samples=-1
# %env test_n_samples=-1

# %env batch_size=16
# %env max_epoch=100

# %env dump_path=/home/jupyter/models/africa/cluster1

# supervised MT
#%env mt_steps=Bafia-en,en-Bafia,Bulu-en,en-Bulu,MKPAMAN_AMVOE_Ewondo-en,en-MKPAMAN_AMVOE_Ewondo,Bafia-fr,fr-Bafia,Bulu-fr,fr-Bulu,MKPAMAN_AMVOE_Ewondo-fr,fr-MKPAMAN_AMVOE_Ewondo
# %env mt_steps=Bafia-fr,fr-Bafia,Bulu-fr,fr-Bulu,MKPAMAN_AMVOE_Ewondo-fr,fr-MKPAMAN_AMVOE_Ewondo
! python train.py --exp_name SupMT_cluster1fr --exp_id $exp_id  --dump_path $dump_path --reload_model $reload_model --data_path $OUTPATH --lgs $lgs --ae_steps $ae_steps --mt_steps $mt_steps --bt_steps $bt_steps --word_shuffle 3 --word_dropout 0.1 --word_blank 0.1 --lambda_ae '0:1,100000:0.1,300000:0' --encoder_only false --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout 0.1 --attention_dropout 0.1 --gelu_activation true --tokens_per_batch 2000 --batch_size $batch_size --bptt 256 --optimizer adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001 --epoch_size $epoch_size --max_epoch $max_epoch --eval_bleu $eval_bleu --stopping_criterion $stopping_criterion --validation_metrics $validation_metrics --train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples --remove_long_sentences_train $remove_long_sentences_train --remove_long_sentences_valid $remove_long_sentences_valid --remove_long_sentences_test $remove_long_sentences_test
# Out:
# env: stopping_criterion=valid_fr-Bulu_mt_bleu,10
# env: validation_metrics=valid_fr-Bulu_mt_bleu
# env: reload_model=/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth,/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth
# env: ae_steps=fr,Bafia,Bulu,MKPAMAN_AMVOE_Ewondo
# env: bt_steps=Bafia-fr-Bafia,fr-Bafia-fr,Bulu-fr-Bulu,fr-Bulu-fr,MKPAMAN_AMVOE_Ewondo-fr-MKPAMAN_AMVOE_Ewondo,fr-MKPAMAN_AMVOE_Ewondo-fr
# env: train_n_samples=-1
# env: valid_n_samples=-1
# env: test_n_samples=-1
# env: batch_size=16
# env: max_epoch=100
# env: dump_path=/home/jupyter/models/africa/cluster1
# env: mt_steps=Bafia-fr,fr-Bafia,Bulu-fr,fr-Bulu,MKPAMAN_AMVOE_Ewondo-fr,fr-MKPAMAN_AMVOE_Ewondo
# FAISS library was not found.
# FAISS not available. Switching to standard nearest neighbors search implementation.
# SLURM job: False
# 0 - Number of nodes: 1
# 0 - Node ID        : 0
# 0 - Local rank     : 0
# 0 - Global rank    : 0
# 0 - World size     : 1
# 0 - GPUs per node  : 1
# 0 - Master         : True
# 0 - Multi-node     : False
# 0 - Multi-GPU      : False
# 0 - Hostname       : african-translator-vm-bis-vm
# INFO - 05/30/20 15:37:24 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/30/20 15:37:24 - 0:00:00 - accumulate_gradients: 1
#                                      ae_steps: ['fr', 'Bafia', 'Bulu', 'MKPAMAN_AMVOE_Ewondo']
#                                      amp: -1
#                                      asm: False
#                                      attention_dropout: 0.1
#                                      batch_size: 16
#                                      beam_size: 1
#                                      bptt: 256
#                                      bt_src_langs: ['Bafia', 'fr', 'Bulu', 'fr', 'MKPAMAN_AMVOE_Ewondo', 'fr']
#                                      bt_steps: [('Bafia', 'fr', 'Bafia'), ('fr', 'Bafia', 'fr'), ('Bulu', 'fr', 'Bulu'), ('fr', 'Bulu', 'fr'), ('MKPAMAN_AMVOE_Ewondo', 'fr', 'MKPAMAN_AMVOE_Ewondo'), ('fr', 'MKPAMAN_AMVOE_Ewondo', 'fr')]
#                                      clip_grad_norm: 5
#                                      clm_steps: []
#                                      command: python train.py --exp_name SupMT_cluster1fr --exp_id maml --dump_path '/home/jupyter/models/africa/cluster1' --reload_model '/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth,/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth' --data_path '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed' --lgs 'en-fr-Bafia-Bulu-MKPAMAN_AMVOE_Ewondo' --ae_steps 'fr,Bafia,Bulu,MKPAMAN_AMVOE_Ewondo' --mt_steps 'Bafia-fr,fr-Bafia,Bulu-fr,fr-Bulu,MKPAMAN_AMVOE_Ewondo-fr,fr-MKPAMAN_AMVOE_Ewondo' --bt_steps 'Bafia-fr-Bafia,fr-Bafia-fr,Bulu-fr-Bulu,fr-Bulu-fr,MKPAMAN_AMVOE_Ewondo-fr-MKPAMAN_AMVOE_Ewondo,fr-MKPAMAN_AMVOE_Ewondo-fr' --word_shuffle 3 --word_dropout '0.1' --word_blank '0.1' --lambda_ae '0:1,100000:0.1,300000:0' --encoder_only false --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout '0.1' --attention_dropout '0.1' --gelu_activation true --tokens_per_batch 2000 --batch_size 16 --bptt 256 --optimizer 'adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001' --epoch_size 23118 --max_epoch 100 --eval_bleu true --stopping_criterion 'valid_fr-Bulu_mt_bleu,10' --validation_metrics 'valid_fr-Bulu_mt_bleu' --train_n_samples '-1' --valid_n_samples '-1' --test_n_samples '-1' --remove_long_sentences_train True --remove_long_sentences_valid True --remove_long_sentences_test True --exp_id "maml"
#                                      context_size: 0
#                                      data_path: /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed
#                                      debug: False
#                                      debug_slurm: False
#                                      debug_train: False
#                                      dropout: 0.1
#                                      dump_path: /home/jupyter/models/africa/cluster1/SupMT_cluster1fr/maml
#                                      early_stopping: False
#                                      emb_dim: 1024
#                                      encoder_only: False
#                                      epoch_size: 23118
#                                      eval_bleu: True
#                                      eval_only: False
#                                      exp_id: maml
#                                      exp_name: SupMT_cluster1fr
#                                      fp16: False
#                                      gelu_activation: True
#                                      global_rank: 0
#                                      group_by_size: True
#                                      id2lang: {0: 'Bafia', 1: 'Bulu', 2: 'MKPAMAN_AMVOE_Ewondo', 3: 'en', 4: 'fr'}
#                                      is_master: True
#                                      is_slurm_job: False
#                                      lambda_ae: 0:1,100000:0.1,300000:0
#                                      lambda_bt: 1
#                                      lambda_clm: 1
#                                      lambda_mlm: 1
#                                      lambda_mt: 1
#                                      lambda_pc: 1
#                                      lang2id: {'Bafia': 0, 'Bulu': 1, 'MKPAMAN_AMVOE_Ewondo': 2, 'en': 3, 'fr': 4}
#                                      langs: ['en', 'fr', 'Bafia', 'Bulu', 'MKPAMAN_AMVOE_Ewondo']
#                                      length_penalty: 1
#                                      lg_sampling_factor: -1
#                                      lgs: ['en-fr-Bafia-Bulu-MKPAMAN_AMVOE_Ewondo']
#                                      local_rank: 0
#                                      master_port: -1
#                                      max_batch_size: 0
#                                      max_epoch: 100
#                                      max_len: 100
#                                      max_vocab: -1
#                                      meta_learning: False
#                                      meta_params: ...
#                                      min_count: 0
#                                      mlm_steps: []
#                                      mono_dataset: {'fr': {'train': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.fr.pth', 'valid': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.fr.pth', 'test': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.fr.pth'}, 'Bafia': {'train': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.Bafia.pth', 'valid': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bafia.pth', 'test': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bafia.pth'}, 'Bulu': {'train': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.Bulu.pth', 'valid': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bulu.pth', 'test': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bulu.pth'}, 'MKPAMAN_AMVOE_Ewondo': {'train': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.MKPAMAN_AMVOE_Ewondo.pth', 'valid': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.MKPAMAN_AMVOE_Ewondo.pth', 'test': '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.MKPAMAN_AMVOE_Ewondo.pth'}}
#                                      mt_steps: [('Bafia', 'fr'), ('fr', 'Bafia'), ('Bulu', 'fr'), ('fr', 'Bulu'), ('MKPAMAN_AMVOE_Ewondo', 'fr'), ('fr', 'MKPAMAN_AMVOE_Ewondo')]
#                                      multi_gpu: False
#                                      multi_node: False
#                                      n_gpu_per_node: 1
#                                      n_heads: 8
#                                      n_langs: 5
#                                      n_layers: 6
#                                      n_nodes: 1
#                                      n_samples: {'train': -1, 'valid': -1, 'test': -1}
#                                      n_task: 1
#                                      node_id: 0
#                                      optimizer: adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001
#                                      para_dataset: {('Bafia', 'fr'): {'train': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.Bafia-fr.Bafia.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.Bafia-fr.fr.pth'), 'valid': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bafia-fr.Bafia.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bafia-fr.fr.pth'), 'test': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bafia-fr.Bafia.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bafia-fr.fr.pth')}, ('Bulu', 'fr'): {'train': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.Bulu-fr.Bulu.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.Bulu-fr.fr.pth'), 'valid': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bulu-fr.Bulu.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bulu-fr.fr.pth'), 'test': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bulu-fr.Bulu.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bulu-fr.fr.pth')}, ('MKPAMAN_AMVOE_Ewondo', 'fr'): {'train': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.MKPAMAN_AMVOE_Ewondo-fr.MKPAMAN_AMVOE_Ewondo.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.MKPAMAN_AMVOE_Ewondo-fr.fr.pth'), 'valid': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.MKPAMAN_AMVOE_Ewondo-fr.MKPAMAN_AMVOE_Ewondo.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.MKPAMAN_AMVOE_Ewondo-fr.fr.pth'), 'test': ('/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.MKPAMAN_AMVOE_Ewondo-fr.MKPAMAN_AMVOE_Ewondo.pth', '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.MKPAMAN_AMVOE_Ewondo-fr.fr.pth')}}
#                                      pc_steps: []
#                                      reload_checkpoint:
#                                      reload_emb:
#                                      reload_model: /home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth,/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth
#                                      remove_long_sentences: {'train': True, 'valid': True, 'test': True}
#                                      remove_long_sentences_test: True
#                                      remove_long_sentences_train: True
#                                      remove_long_sentences_valid: True
#                                      same_data_path: True
#                                      sample_alpha: 0
#                                      save_periodic: 0
#                                      share_inout_emb: True
#                                      sinusoidal_embeddings: False
#                                      split_data: False
#                                      stopping_criterion: valid_fr-Bulu_mt_bleu,10
#                                      test_n_samples: -1
#                                      tokens_per_batch: 2000
#                                      train_n_samples: -1
#                                      use_lang_emb: True
#                                      use_memory: False
#                                      valid_n_samples: -1
#                                      validation_metrics: valid_fr-Bulu_mt_bleu
#                                      word_blank: 0.1
#                                      word_dropout: 0.1
#                                      word_keep: 0.1
#                                      word_mask: 0.8
#                                      word_mask_keep_rand: 0.8,0.1,0.1
#                                      word_pred: 0.15
#                                      word_rand: 0.1
#                                      word_shuffle: 3.0
#                                      world_size: 1
# INFO - 05/30/20 15:37:24 - 0:00:00 - The experiment will be stored in /home/jupyter/models/africa/cluster1/SupMT_cluster1fr/maml
#
# INFO - 05/30/20 15:37:24 - 0:00:00 - Running command: python train.py --exp_name SupMT_cluster1fr --exp_id maml --dump_path '/home/jupyter/models/africa/cluster1' --reload_model '/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth,/home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth' --data_path '/home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed' --lgs 'en-fr-Bafia-Bulu-MKPAMAN_AMVOE_Ewondo' --ae_steps 'fr,Bafia,Bulu,MKPAMAN_AMVOE_Ewondo' --mt_steps 'Bafia-fr,fr-Bafia,Bulu-fr,fr-Bulu,MKPAMAN_AMVOE_Ewondo-fr,fr-MKPAMAN_AMVOE_Ewondo' --bt_steps 'Bafia-fr-Bafia,fr-Bafia-fr,Bulu-fr-Bulu,fr-Bulu-fr,MKPAMAN_AMVOE_Ewondo-fr-MKPAMAN_AMVOE_Ewondo,fr-MKPAMAN_AMVOE_Ewondo-fr' --word_shuffle 3 --word_dropout '0.1' --word_blank '0.1' --lambda_ae '0:1,100000:0.1,300000:0' --encoder_only false --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout '0.1' --attention_dropout '0.1' --gelu_activation true --tokens_per_batch 2000 --batch_size 16 --bptt 256 --optimizer 'adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001' --epoch_size 23118 --max_epoch 100 --eval_bleu true --stopping_criterion 'valid_fr-Bulu_mt_bleu,10' --validation_metrics 'valid_fr-Bulu_mt_bleu' --train_n_samples '-1' --valid_n_samples '-1' --test_n_samples '-1' --remove_long_sentences_train True --remove_long_sentences_valid True --remove_long_sentences_test True
#
# WARNING - 05/30/20 15:37:24 - 0:00:00 - Signal handler installed.
# INFO - 05/30/20 15:37:24 - 0:00:00 - ============ langs: en, fr, Bafia, Bulu, MKPAMAN_AMVOE_Ewondo
# INFO - 05/30/20 15:37:24 - 0:00:00 - ============ Monolingual data (fr)
# INFO - 05/30/20 15:37:24 - 0:00:00 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed
- Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bulu-fr.Bulu.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 86579 words (44986 unique) in 2889 sentences. 6 unknown words (6 unique) covering 0.01% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.Bulu-fr.fr.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 86440 words (44986 unique) in 2889 sentences. 11 unknown words (9 unique) covering 0.01% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - ========================== debug : 29
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 empty sentences.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 1 too long sentences.
#
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bulu-fr.Bulu.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 87739 words (44986 unique) in 2889 sentences. 10 unknown words (9 unique) covering 0.01% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.Bulu-fr.fr.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 87441 words (44986 unique) in 2889 sentences. 12 unknown words (11 unique) covering 0.01% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - ========================== debug : 30
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 empty sentences.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 too long sentences.
#
# INFO - 05/30/20 15:37:26 - 0:00:02 - ============ Parallel data (MKPAMAN_AMVOE_Ewondo-fr)
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.MKPAMAN_AMVOE_Ewondo-fr.MKPAMAN_AMVOE_Ewondo.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 148427 words (44986 unique) in 6356 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/train.MKPAMAN_AMVOE_Ewondo-fr.fr.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 175252 words (44986 unique) in 6356 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - ========================== debug : 31
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 empty sentences.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 empty sentences.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 too long sentences.
#
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.MKPAMAN_AMVOE_Ewondo-fr.MKPAMAN_AMVOE_Ewondo.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 18922 words (44986 unique) in 794 sentences. 9 unknown words (9 unique) covering 0.05% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/valid.MKPAMAN_AMVOE_Ewondo-fr.fr.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 22011 words (44986 unique) in 794 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - ========================== debug : 32
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 empty sentences.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Removed 0 too long sentences.
#
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.MKPAMAN_AMVOE_Ewondo-fr.MKPAMAN_AMVOE_Ewondo.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:02 - 18785 words (44986 unique) in 794 sentences. 11 unknown words (11 unique) covering 0.06% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:02 - Loading data from /home/jupyter/models/africa/cluster1/data/multi_xlm_enfr/processed/test.MKPAMAN_AMVOE_Ewondo-fr.fr.pth ...
# INFO - 05/30/20 15:37:26 - 0:00:03 - 22267 words (44986 unique) in 794 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
# INFO - 05/30/20 15:37:26 - 0:00:03 - ========================== debug : 33
# INFO - 05/30/20 15:37:26 - 0:00:03 - Removed 0 empty sentences.
# INFO - 05/30/20 15:37:26 - 0:00:03 - Removed 0 too long sentences.
#
#
# INFO - 05/30/20 15:37:26 - 0:00:03 - ============ Data summary
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - train -           fr:     25039
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - valid -           fr:      3129
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   -  test -           fr:      3129
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - train -        Bafia:      6360
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - valid -        Bafia:       795
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   -  test -        Bafia:       795
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - train -         Bulu:     23117
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - valid -         Bulu:      2889
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   -  test -         Bulu:      2889
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - train - MKPAMAN_AMVOE_Ewondo:      6356
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   - valid - MKPAMAN_AMVOE_Ewondo:       794
# INFO - 05/30/20 15:37:26 - 0:00:03 - Monolingual data   -  test - MKPAMAN_AMVOE_Ewondo:       794
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      - train -     Bafia-fr:      6327
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      - valid -     Bafia-fr:       789
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      -  test -     Bafia-fr:       794
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      - train -      Bulu-fr:     23114
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      - valid -      Bulu-fr:      2888
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      -  test -      Bulu-fr:      2889
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      - train - MKPAMAN_AMVOE_Ewondo-fr:      6356
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      - valid - MKPAMAN_AMVOE_Ewondo-fr:       794
# INFO - 05/30/20 15:37:26 - 0:00:03 - Parallel data      -  test - MKPAMAN_AMVOE_Ewondo-fr:       794
#
# INFO - 05/30/20 15:37:30 - 0:00:06 - Reloading encoder from /home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth ...
# INFO - 05/30/20 15:37:36 - 0:00:13 - Reloading decoder from /home/jupyter/models/africa/cluster1/mlm_tlm_cluster1enfr/maml/best-valid_mlm_ppl.pth ...
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.0.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.0.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.q_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.q_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.k_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.k_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.v_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.v_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.out_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.0.out_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.1.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.1.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.q_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.q_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.k_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.k_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.v_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.v_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.out_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.1.out_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.2.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.2.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.q_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.q_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.k_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.k_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.v_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.v_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.out_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.2.out_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.3.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.3.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.q_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.q_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.k_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.k_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.v_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.v_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.out_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.3.out_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.4.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.4.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.q_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.q_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.k_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.k_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.v_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.v_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.out_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.4.out_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.5.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter layer_norm15.5.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.q_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.q_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.k_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.k_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.v_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.v_lin.bias not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.out_lin.weight not found.
# WARNING - 05/30/20 15:37:37 - 0:00:13 - Parameter encoder_attn.5.out_lin.bias not found.
# INFO - 05/30/20 15:37:37 - 0:00:13 - Number of parameters (encoder): 122219450
# INFO - 05/30/20 15:37:37 - 0:00:13 - Number of parameters (decoder): 147422138
# INFO - 05/30/20 15:37:37 - 0:00:14 - Found 0 memories.
# INFO - 05/30/20 15:37:37 - 0:00:14 - Found 12 FFN.
# INFO - 05/30/20 15:37:37 - 0:00:14 - Found 264 parameters in model.
# Traceback (most recent call last):
#   File "train.py", line 627, in <module>
#     main(params)
#   File "train.py", line 287, in main
#     trainer = EncDecTrainer(encoder, decoder, data, params)
#   File "/home/jupyter/meta_XLM/XLM/src/trainer.py", line 1143, in __init__
#     super().__init__(data, params)
#   File "/home/jupyter/meta_XLM/XLM/src/trainer.py", line 69, in __init__
#     self.set_optimizers()
#   File "/home/jupyter/meta_XLM/XLM/src/trainer.py", line 192, in set_optimizers
#     self.optimizers['model'] = get_optimizer(self.parameters['model'], params.optimizer)
#   File "/home/jupyter/meta_XLM/XLM/src/optim.py", line 270, in get_optimizer
#     return optim_fn(parameters, **optim_params)
#   File "/home/jupyter/meta_XLM/XLM/src/optim.py", line 112, in __init__
#     weight_decay=weight_decay,
#   File "/home/jupyter/meta_XLM/XLM/src/optim.py", line 40, in __init__
#     state['exp_avg_sq'] = torch.zeros_like(p.data)
# RuntimeError: CUDA out of memory. Tried to allocate 16.00 MiB (GPU 0; 14.73 GiB total capacity; 2.56 GiB already allocated; 18.88 MiB free; 2.57 GiB reserved in total by PyTorch)
