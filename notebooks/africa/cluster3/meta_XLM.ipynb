# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
! git clone https://github.com/Tikquuss/meta_XLM /content/meta_XLM
# Out:
# Cloning into '/content/meta_XLM'...
# remote: Enumerating objects: 282, done.
# remote: Counting objects: 100% (282/282), done.
# remote: Compressing objects: 100% (202/202), done.
# remote: Total 517 (delta 193), reused 156 (delta 79), pack-reused 235
# Receiving objects: 100% (517/517), 30.45 MiB | 18.27 MiB/s, done.
# Resolving deltas: 100% (239/239), done.

# %% [markdown]
# # **A ce niveau si on a des données deja traitées, on copie juste**

# %% [markdown]
# **1) On a pas les données**

# %%
! cp -R /content/drive/"My Drive"/African_Translator/datasets/YourVersion/csvs /content

# %%
# %bookmark HOME "/content/meta_XLM/XLM" 
# %cd -b HOME
# Out:
# (bookmark:HOME) -> /content/meta_XLM/XLM
# /content/meta_XLM/XLM

# %%
# %cd tools
! git clone https://github.com/moses-smt/mosesdecoder
! git clone https://github.com/glample/fastBPE && cd fastBPE && g++ -std=c++11 -pthread -O3 fastBPE/main.cc -IfastBPE -o fast
# Out:
# /content/meta_XLM/XLM/tools
# Cloning into 'mosesdecoder'...
# remote: Enumerating objects: 30, done.
# remote: Counting objects: 100% (30/30), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 147544 (delta 12), reused 15 (delta 5), pack-reused 147514
# Receiving objects: 100% (147544/147544), 129.75 MiB | 22.46 MiB/s, done.
# Resolving deltas: 100% (113998/113998), done.
# Cloning into 'fastBPE'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 59 (delta 0), reused 1 (delta 0), pack-reused 54
# Unpacking objects: 100% (59/59), done.

# %%
# %cd -b HOME
# Out:
# (bookmark:HOME) -> /content/meta_XLM/XLM
# /content/meta_XLM/XLM

# %%
! mkdir data

# %%
# %env csv_path=/content
# %env output_dir=data
# %env data_type=para
# %env languages=Bafia,Bulu,MKPAMAN_AMVOE_Ewondo
! python ../bible.py --csv_path $csv_path --output_dir $output_dir --data_type $data_type --languages $languages
# Out:
# env: csv_path=/content
# env: output_dir=data
# env: data_type=para
# env: languages=Bafia,Bulu,MKPAMAN_AMVOE_Ewondo
# Bafia - Bulu
# ======= Read 7950 totals samples
# ======= Delete 4 samples
# ======= Save 7946 samples
# Bulu
# ======= Read 31297 totals samples
# ======= Delete 2402 samples
# ======= Save 28895 samples
# Bafia - MKPAMAN_AMVOE_Ewondo
# ======= Read 7950 totals samples
# ======= Delete 6 samples
# ======= Save 7944 samples
# Bulu - MKPAMAN_AMVOE_Ewondo
# ======= Read 7950 totals samples
# ======= Delete 10 samples
# ======= Save 7940 samples
# Bulu
# ======= Read 31297 totals samples
# ======= Delete 2402 samples
# ======= Save 28895 samples

# %%
# comme il y a une partie de données mono disponible pour l'une des langues, on genre une fois pour l'autre
! cp data/para/Bafia-Bulu/Bafia-Bulu.Bafia.txt  data/mono
! mv data/mono/Bafia-Bulu.Bafia.txt data/mono/Bafia.txt

! cp data/para/Bafia-MKPAMAN_AMVOE_Ewondo/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.txt  data/mono
! mv data/mono/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.txt data/mono/MKPAMAN_AMVOE_Ewondo.txt
# put everything in one place
! cp data/mono/Bulu/Bulu.txt data/mono
! rm -R data/mono/Bulu

# %%
# mettre les données para dans un seul dossier
! mkdir data/para/all
! cp data/para/Bafia-Bulu/*.txt data/para/all
! cp data/para/Bafia-MKPAMAN_AMVOE_Ewondo/*.txt data/para/all
! cp data/para/Bulu-MKPAMAN_AMVOE_Ewondo/*.txt data/para/all

# %%
# %env PARA=True          
# %env MONO=True       
                   
# %env PARA_PATH=data/para/all     
# %env MONO_PATH=data/mono   
# %env SAME_VOCAB=True   
# on augmente le nombre de code 
# %env nCodes=20000             
# %env shuf_n_samples=1000000   
# %env threads_for_tokenizer=16 
# %env test_size=10             
# %env val_size=10              

# tools paths
# %env TOKENIZE=tools/tokenizer_our.sh
# %env LOWER_REMOVE_ACCENT=tools/lowercase_and_remove_accent.py
# %env FASTBPE=tools/fastBPE/fast


# %env OUTPATH=data/processed
# create output path
! mkdir -p $OUTPATH

! chmod +x $FASTBPE
! chmod +x ../build_meta_data.sh
! chmod +x tools/mosesdecoder/scripts/tokenizer/*.perl

# %env n_samples=-1

# %env sub_task=Bafia-Bulu:-1,Bafia-MKPAMAN_AMVOE_Ewondo:-1,Bulu-MKPAMAN_AMVOE_Ewondo:-1
# Out:
# env: PARA=True
# env: MONO=True
# env: PARA_PATH=data/para/all
# env: MONO_PATH=data/mono
# env: SAME_VOCAB=True
# env: nCodes=20000
# env: shuf_n_samples=1000000
# env: threads_for_tokenizer=16
# env: test_size=10
# env: val_size=10
# env: TOKENIZE=tools/tokenizer_our.sh
# env: LOWER_REMOVE_ACCENT=tools/lowercase_and_remove_accent.py
# env: FASTBPE=tools/fastBPE/fast
# env: OUTPATH=data/processed
# env: n_samples=-1
# env: sub_task=Bafia-Bulu:-1,Bafia-MKPAMAN_AMVOE_Ewondo:-1,Bulu-MKPAMAN_AMVOE_Ewondo:-1

# %%
# %env add_para_data_to_mono_data=False
! ../build_meta_data.sh $sub_task $n_samples $add_para_data_to_mono_data
# Out:
# env: add_para_data_to_mono_data=False
# params ok !
# *** Cleaning and tokenizing Bafia-Bulu data ... ***
# Tokenizer Version 1.1
# Language: Bafia
# Number of threads: 8
# WARNING: No known abbreviations for language 'Bafia', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bafia-Bulu.Bafia data to data/para/all/? ***
# Tokenizer Version 1.1
# Language: Bulu
# Number of threads: 8
# WARNING: No known abbreviations for language 'Bulu', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bafia-Bulu.Bulu data to data/para/all/? ***
# *** Cleaning and tokenizing Bafia-MKPAMAN_AMVOE_Ewondo data ... ***
# Tokenizer Version 1.1
# Language: Bafia
# Number of threads: 8
# WARNING: No known abbreviations for language 'Bafia', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bafia-MKPAMAN_AMVOE_Ewondo.Bafia data to data/para/all/? ***
# Tokenizer Version 1.1
# Language: MKPAMAN_AMVOE_Ewondo
# Number of threads: 8
# WARNING: No known abbreviations for language 'MKPAMAN_AMVOE_Ewondo', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo data to data/para/all/? ***
# *** Cleaning and tokenizing Bulu-MKPAMAN_AMVOE_Ewondo data ... ***
# Tokenizer Version 1.1
# Language: Bulu
# Number of threads: 8
# WARNING: No known abbreviations for language 'Bulu', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bulu-MKPAMAN_AMVOE_Ewondo.Bulu data to data/para/all/? ***
# Tokenizer Version 1.1
# Language: MKPAMAN_AMVOE_Ewondo
# Number of threads: 8
# WARNING: No known abbreviations for language 'MKPAMAN_AMVOE_Ewondo', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo data to data/para/all/? ***
# Tokenizer Version 1.1
# Language: Bafia
# Number of threads: 8
# WARNING: No known abbreviations for language 'Bafia', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bafia data to data/mono/? ***
# Tokenizer Version 1.1
# Language: Bulu
# Number of threads: 8
# WARNING: No known abbreviations for language 'Bulu', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) Bulu data to data/mono/? ***
# file data/mono/Bafia.all already exists
# Tokenizer Version 1.1
# Language: MKPAMAN_AMVOE_Ewondo
# Number of threads: 8
# WARNING: No known abbreviations for language 'MKPAMAN_AMVOE_Ewondo', attempting fall-back to English version...
# *** Tokenized (+ lowercase + accent-removal) MKPAMAN_AMVOE_Ewondo data to data/mono/? ***
# file data/mono/Bulu.all already exists
# file data/mono/MKPAMAN_AMVOE_Ewondo.all already exists
#
#
# *** split into train / valid / test ***
#
#
#
# ***build the training set for BPE tokenization (20000 codes)***
#
#
# ***shuf ... Generating 1000000 random permutations of training data and store result in data/processed/Bulu-MKPAMAN_AMVOE_Ewondo/bpe.train***
#
#
# ***Learn the BPE vocabulary on the training set : data/processed/bpe.train ...***
# Loading vocabulary from data/processed/bpe.train ...
# Read 382169532 words (22180 unique) from text file.
# tcmalloc: large alloc 12000002048 bytes == 0x564af5e68000 @  0x7feab9f2e887 0x564af36998f3 0x564af368e78f 0x7feab9369b97 0x564af368ea1a
# ***Learn 20000 BPE code on the bpe.train file***
#
#
# ***Get the post-BPE vocab***
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/processed/bpe.train ...
# Read 382169532 words (22180 unique) from text file.
# Applying BPE to data/processed/bpe.train ...
# Modified 382169532 words from text file.
# Read 383140803 words (18197 unique) from text file.
#
#
# ***Apply BPE tokenization on the corpora.***
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-Bulu.Bafia.train ...
# Read 273575 words (4738 unique) from text file.
# Applying BPE to data/para/all/Bafia-Bulu.Bafia.train ...
# Modified 273575 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-Bulu.Bafia.valid ...
# Read 34193 words (1929 unique) from text file.
# Applying BPE to data/para/all/Bafia-Bulu.Bafia.valid ...
# Modified 34193 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-Bulu.Bafia.test ...
# Read 34625 words (1959 unique) from text file.
# Applying BPE to data/para/all/Bafia-Bulu.Bafia.test ...
# Modified 34625 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-Bulu.Bulu.train ...
# Read 179829 words (4871 unique) from text file.
# Applying BPE to data/para/all/Bafia-Bulu.Bulu.train ...
# Modified 179829 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-Bulu.Bulu.valid ...
# Read 22654 words (2052 unique) from text file.
# Applying BPE to data/para/all/Bafia-Bulu.Bulu.valid ...
# Modified 22654 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-Bulu.Bulu.test ...
# Read 22753 words (2107 unique) from text file.
# Applying BPE to data/para/all/Bafia-Bulu.Bulu.test ...
# Modified 22753 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.train ...
# Read 273698 words (4743 unique) from text file.
# Applying BPE to data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.train ...
# Modified 273698 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.valid ...
# Read 34658 words (1957 unique) from text file.
# Applying BPE to data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.valid ...
# Modified 34658 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.test ...
# Read 33987 words (1926 unique) from text file.
# Applying BPE to data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.test ...
# Modified 33987 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.train ...
# Read 148418 words (6898 unique) from text file.
# Applying BPE to data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.train ...
# Modified 148418 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.valid ...
# Read 18748 words (2528 unique) from text file.
# Applying BPE to data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.valid ...
# Modified 18748 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.test ...
# Read 18332 words (2563 unique) from text file.
# Applying BPE to data/para/all/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.test ...
# Modified 18332 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.train ...
# Read 180125 words (4890 unique) from text file.
# Applying BPE to data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.train ...
# Modified 180125 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.valid ...
# Read 22336 words (2002 unique) from text file.
# Applying BPE to data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.valid ...
# Modified 22336 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.test ...
# Read 22648 words (2143 unique) from text file.
# Applying BPE to data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.test ...
# Modified 22648 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.train ...
# Read 148369 words (6918 unique) from text file.
# Applying BPE to data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.train ...
# Modified 148369 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.valid ...
# Read 18429 words (2488 unique) from text file.
# Applying BPE to data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.valid ...
# Modified 18429 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.test ...
# Read 18611 words (2525 unique) from text file.
# Applying BPE to data/para/all/Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.test ...
# Modified 18611 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/Bafia.train ...
# Read 273575 words (4738 unique) from text file.
# Applying BPE to data/mono/Bafia.train ...
# Modified 273575 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/Bafia.valid ...
# Read 34193 words (1929 unique) from text file.
# Applying BPE to data/mono/Bafia.valid ...
# Modified 34193 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/Bafia.test ...
# Read 34625 words (1959 unique) from text file.
# Applying BPE to data/mono/Bafia.test ...
# Modified 34625 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/Bulu.train ...
# Read 693166 words (11175 unique) from text file.
# Applying BPE to data/mono/Bulu.train ...
# Modified 693166 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/Bulu.valid ...
# Read 86467 words (4734 unique) from text file.
# Applying BPE to data/mono/Bulu.valid ...
# Modified 86467 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/Bulu.test ...
# Read 86828 words (4589 unique) from text file.
# Applying BPE to data/mono/Bulu.test ...
# Modified 86828 words from text file.
# file data/processed/train.Bafia already exists
# file data/processed/valid.Bafia already exists
# file data/processed/test.Bafia already exists
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/MKPAMAN_AMVOE_Ewondo.train ...
# Read 148418 words (6898 unique) from text file.
# Applying BPE to data/mono/MKPAMAN_AMVOE_Ewondo.train ...
# Modified 148418 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/MKPAMAN_AMVOE_Ewondo.valid ...
# Read 18748 words (2528 unique) from text file.
# Applying BPE to data/mono/MKPAMAN_AMVOE_Ewondo.valid ...
# Modified 18748 words from text file.
# Loading codes from data/processed/codes ...
# Read 20000 codes from the codes file.
# Loading vocabulary from data/mono/MKPAMAN_AMVOE_Ewondo.test ...
# Read 18332 words (2563 unique) from text file.
# Applying BPE to data/mono/MKPAMAN_AMVOE_Ewondo.test ...
# Modified 18332 words from text file.
# file data/processed/train.Bulu already exists
# file data/processed/valid.Bulu already exists
# file data/processed/test.Bulu already exists
# file data/processed/train.MKPAMAN_AMVOE_Ewondo already exists
# file data/processed/valid.MKPAMAN_AMVOE_Ewondo already exists
# file data/processed/test.MKPAMAN_AMVOE_Ewondo already exists
#
#
# ***Build fine_tune data***
#
#
# ***Binarize everything using preprocess.py.***
# INFO - 05/18/20 21:09:11 - 0:00:00 - Read 18211 words from the vocabulary file.
#
# Saving the data to data/processed/Bafia-Bulu.Bafia.train.pth ...
# INFO - 05/18/20 21:09:12 - 0:00:00 - 273575 words (18211 unique) in 6359 sentences.
# INFO - 05/18/20 21:09:13 - 0:00:00 - Read 18211 words from the vocabulary file.
#
# Saving the data to data/processed/Bafia-Bulu.Bafia.valid.pth ...
# INFO - 05/18/20 21:09:13 - 0:00:00 - 34423 words (18211 unique) in 794 sentences.
# INFO - 05/18/20 21:09:13 - 0:00:00 - 8 unknown words (8 unique), covering 0.02% of the data.
# INFO - 05/18/20 21:09:13 - 0:00:00 - wɛɛ@@: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - roo@@: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - ɓsii: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - oze@@: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - ap@@: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - zɛɛ@@: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - sɛ@@: 1
# INFO - 05/18/20 21:09:13 - 0:00:00 - ɛr: 1
# INFO - 05/18/20 21:09:14 - 0:00:00 - Read 18211 words from the vocabulary file.
#
# Saving the data to data/processed
# file data/processed/valid.MKPAMAN_AMVOE_Ewondo.pth already exists
# file data/processed/test.MKPAMAN_AMVOE_Ewondo.pth already exists
#
#
# ***Creat the file to train the XLM model with MLM+TLM objective***
#
#
# *** build data with succes : dir data/processed ***

# %%
# save the data for future training
! mkdir /content/drive/"My Drive"/African_Translator/models/africa/cluster1/data/Bafia-Bulu
! rsync -av --progress data/processed /content/drive/"My Drive"/African_Translator/models/africa/cluster1/data/Bafia-Bulu

# %% [markdown]
# **2) On a les données**

# %%
# %bookmark HOME "/content/meta_XLM/XLM" 
# %cd -b HOME
# Out:
# (bookmark:HOME) -> /content/meta_XLM/XLM
# /content/meta_XLM/XLM

# %%
! rsync -av --progress /content/drive/"My Drive"/African_Translator/models/africa/cluster1/data/Bafia-Bulu/processed data
# Out:
# sending incremental file list
# created directory data
# processed/
# processed/Bafia-Bulu.Bafia.test
#         153,470 100%  115.11MB/s    0:00:00 (xfr#1, to-chk=76/78)
# processed/Bafia-Bulu.Bafia.test.pth
#         594,748 100%    1.55MB/s    0:00:00 (xfr#2, to-chk=75/78)
# processed/Bafia-Bulu.Bafia.train
#       1,208,091 100%    1.40MB/s    0:00:00 (xfr#3, to-chk=74/78)
# processed/Bafia-Bulu.Bafia.train.pth
#       1,172,243 100%  989.43kB/s    0:00:01 (xfr#4, to-chk=73/78)
# processed/Bafia-Bulu.Bafia.valid
#         151,695 100%  470.28kB/s    0:00:00 (xfr#5, to-chk=72/78)
# processed/Bafia-Bulu.Bafia.valid.pth
#         593,841 100%  963.33kB/s    0:00:00 (xfr#6, to-chk=71/78)
# processed/Bafia-Bulu.Bulu.test
#          91,699 100%   92.89kB/s    0:00:00 (xfr#7, to-chk=70/78)
# processed/Bafia-Bulu.Bulu.test.pth
#         570,660 100%  431.67kB/s    0:00:01 (xfr#8, to-chk=69/78)
# processed/Bafia-Bulu.Bulu.train
#         723,269 100%    1.92MB/s    0:00:00 (xfr#9, to-chk=68/78)
# processed/Bafia-Bulu.Bulu.train.pth
#         985,217 100%    1.44MB/s    0:00:00 (xfr#10, to-chk=67/78)
# processed/Bafia-Bulu.Bulu.valid
#          91,562 100%   96.67kB/s    0:00:00 (xfr#11, to-chk=66/78)
# processed/Bafia-Bulu.Bulu.valid.pth
#         570,474 100%  442.50kB/s    0:00:01 (xfr#12, to-chk=65/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.test
#         149,792 100%  334.74kB/s    0:00:00 (xfr#13, to-chk=64/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.test.pth
#         593,073 100%    4.73MB/s    0:00:00 (xfr#14, to-chk=63/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.train
#       1,209,885 100%    2.46MB/s    0:00:00 (xfr#15, to-chk=62/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.train.pth
#       1,173,245 100%    1.25MB/s    0:00:00 (xfr#16, to-chk=61/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.valid
#         153,338 100%  115.72kB/s    0:00:01 (xfr#17, to-chk=60/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.valid.pth
#         594,378 100%  993.92kB/s    0:00:00 (xfr#18, to-chk=59/78)
# processed/Bafia-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo
MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.pth
#         563,048 100%  447.76kB/s    0:00:01 (xfr#68, to-chk=9/78)
# processed/valid.Bafia.pth
#         593,841 100%    3.04MB/s    0:00:00 (xfr#69, to-chk=8/78)
# processed/valid.Bulu
#         356,718 100%  507.07kB/s    0:00:00 (xfr#70, to-chk=7/78)
# processed/valid.Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.pth
#         569,782 100%  584.48kB/s    0:00:00 (xfr#71, to-chk=6/78)
# processed/valid.Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.pth
#         561,968 100%  458.48kB/s    0:00:01 (xfr#72, to-chk=5/78)
# processed/valid.Bulu.pth
#         738,545 100%    1.48MB/s    0:00:00 (xfr#73, to-chk=4/78)
# processed/valid.MKPAMAN_AMVOE_Ewondo
#          81,654 100%  109.99kB/s    0:00:00 (xfr#74, to-chk=3/78)
# processed/valid.MKPAMAN_AMVOE_Ewondo.pth
#         563,048 100%  615.05kB/s    0:00:00 (xfr#75, to-chk=2/78)
# processed/vocab
#         214,226 100%  174.48kB/s    0:00:01 (xfr#76, to-chk=1/78)
# processed/fine_tune/
#
# sent 3,325,737,701 bytes  received 1,499 bytes  18,631,592.16 bytes/sec
# total size is 3,324,921,537  speedup is 1.00

# %% [markdown]
# # **Trainnig**

# %%
# %env OUTPATH=data/processed
# %env exp_id=maml
# If you don't have enough RAM or swap memory, leave these three parameters to True, otherwise you may get an error like this when evaluating 
# RuntimeError: copy_if failed to synchronize: cudaErrorAssert: device-side assert triggered
# %env remove_long_sentences_train=True
# %env remove_long_sentences_valid=True
# %env remove_long_sentences_test=True
#--remove_long_sentences_train $remove_long_sentences_train --remove_long_sentences_valid $remove_long_sentences_valid --remove_long_sentences_test $remove_long_sentences_test
# Out:
# env: OUTPATH=data/processed
# env: exp_id=maml
# env: remove_long_sentences_train=True
# env: remove_long_sentences_valid=True
# env: remove_long_sentences_test=True

# %%
# le plus grand fichier à tensor_len phrases, on cherche le multiple de "batch_size" le plus proche de ce 
# nombre par valeur supérieur : epoch_size doit etre un multiple non nul de ce nombre (pour ne pas gaspiller) 

def getEpochSize(tensor_len, batch_size):
  i = tensor_len
  while True :
    if i%batch_size == 0 :
      return i//batch_size
    i = i + 1

import io

def n_lines(file_path):
  return len(io.open(file_path, encoding='UTF-8').read().split('\n'))

# %%
tensor_len = max(
    n_lines(file_path = "data/processed/Bafia-Bulu.Bafia.train"),
    n_lines(file_path = "data/processed/Bafia-MKPAMAN_AMVOE_Ewondo.Bafia.train"),
    n_lines(file_path = "data/processed/Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.train")
)

print("tensor_len = " + str(tensor_len))
# Out:
# tensor_len = 6360

# %%
# %env epoch_size=6360

# %env lgs=Bafia-Bulu|Bafia-MKPAMAN_AMVOE_Ewondo|Bulu-MKPAMAN_AMVOE_Ewondo

# limit the number of examples (-1 by default for non limitation)
# %env train_n_samples=-1
# %env valid_n_samples=-1
# %env test_n_samples=-1
#--train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples

# stopping criterion (if criterion does not improve 10 times)
# %env stopping_criterion=_valid_mlm_ppl,10
# %env eval_bleu false
# Out:
# env: epoch_size=6360
# env: lgs=Bafia-Bulu|Bafia-MKPAMAN_AMVOE_Ewondo|Bulu-MKPAMAN_AMVOE_Ewondo
# env: train_n_samples=-1
# env: valid_n_samples=-1
# env: test_n_samples=-1
# env: stopping_criterion=_valid_mlm_ppl,10
# env: eval_bleu=false

# %% [markdown]
# **Si on a un model pre-entrainé, le mettre en place**

# %%
! rsync -av --progress /content/drive/"My Drive"/African_Translator/models/africa/cluster1/mlm_tlm_BafiaBuluEwondo /content/meta_XLM/XLM/dumped
# Out:
# sending incremental file list
# created directory /content/meta_XLM/XLM/dumped
# mlm_tlm_BafiaBuluEwondo/
# mlm_tlm_BafiaBuluEwondo/maml/
# mlm_tlm_BafiaBuluEwondo/maml/best-valid_mlm_ppl.pth
#     379,907,028 100%   41.70MB/s    0:00:08 (xfr#1, to-chk=16/19)
# mlm_tlm_BafiaBuluEwondo/maml/checkpoint.pth
#   1,138,112,989 100%   16.61MB/s    0:01:05 (xfr#2, to-chk=15/19)
# mlm_tlm_BafiaBuluEwondo/maml/params.pkl
#           3,597 100%    0.00kB/s    0:00:00 (xfr#3, to-chk=14/19)
# mlm_tlm_BafiaBuluEwondo/maml/train.log
#         357,997 100%  950.02kB/s    0:00:00 (xfr#4, to-chk=13/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-Bulu.test.txt
#          90,637 100%  122.26kB/s    0:00:00 (xfr#5, to-chk=11/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-Bulu.valid.txt
#          90,425 100%   83.54kB/s    0:00:01 (xfr#6, to-chk=10/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-MKPAMAN_AMVOE_Ewondo.test.txt
#          78,600 100%  222.49kB/s    0:00:00 (xfr#7, to-chk=9/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-MKPAMAN_AMVOE_Ewondo.valid.txt
#          79,452 100%  119.00kB/s    0:00:00 (xfr#8, to-chk=8/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-Bafia.test.txt
#         136,739 100%  128.27kB/s    0:00:01 (xfr#9, to-chk=7/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-Bafia.valid.txt
#         135,349 100%   97.84kB/s    0:00:01 (xfr#10, to-chk=6/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-MKPAMAN_AMVOE_Ewondo.test.txt
#          80,846 100%  239.25kB/s    0:00:00 (xfr#11, to-chk=5/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-MKPAMAN_AMVOE_Ewondo.valid.txt
#          79,461 100%  114.45kB/s    0:00:00 (xfr#12, to-chk=4/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bafia.test.txt
#         134,447 100%  134.52kB/s    0:00:00 (xfr#13, to-chk=3/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bafia.valid.txt
#         136,106 100%  103.44kB/s    0:00:01 (xfr#14, to-chk=2/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bulu.test.txt
#          91,072 100%  276.20kB/s    0:00:00 (xfr#15, to-chk=1/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bulu.valid.txt
#          89,554 100%  138.38kB/s    0:00:00 (xfr#16, to-chk=0/19)
#
# sent 1,519,976,425 bytes  received 391 bytes  18,423,961.41 bytes/sec
# total size is 1,519,604,299  speedup is 1.00

# %%
# %env mlm_steps=Bafia,Bulu,Bafia-Bulu|Bafia,MKPAMAN_AMVOE_Ewondo,Bafia-MKPAMAN_AMVOE_Ewondo|Bulu,MKPAMAN_AMVOE_Ewondo,Bulu-MKPAMAN_AMVOE_Ewondo
# %env batch_size=4
# %env max_epoch=100
! python train.py --exp_name mlm_tlm_BafiaBuluEwondo --exp_id $exp_id --dump_path ./dumped/ --data_path $OUTPATH --lgs $lgs --clm_steps '' --mlm_steps $mlm_steps --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout 0.1 --attention_dropout 0.1 --gelu_activation true --batch_size $batch_size --bptt 256 --optimizer adam,lr=0.0001 --epoch_size $epoch_size --max_epoch $max_epoch --validation_metrics _valid_mlm_ppl --stopping_criterion $stopping_criterion --eval_bleu $eval_bleu --remove_long_sentences_train $remove_long_sentences_train --remove_long_sentences_valid $remove_long_sentences_valid --remove_long_sentences_test $remove_long_sentences_test --train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples
# Out:
# env: mlm_steps=Bafia,Bulu,Bafia-Bulu|Bafia,MKPAMAN_AMVOE_Ewondo,Bafia-MKPAMAN_AMVOE_Ewondo|Bulu,MKPAMAN_AMVOE_Ewondo,Bulu-MKPAMAN_AMVOE_Ewondo
# env: batch_size=4
# env: max_epoch=100
# FAISS library was not found.
# FAISS not available. Switching to standard nearest neighbors search implementation.
# SLURM job: False
# 0 - Number of nodes: 1
# 0 - Node ID        : 0
# 0 - Local rank     : 0
# 0 - Global rank    : 0
# 0 - World size     : 1
# 0 - GPUs per node  : 1
# 0 - Master         : True
# 0 - Multi-node     : False
# 0 - Multi-GPU      : False
# 0 - Hostname       : 51022818efbd
# INFO - 05/19/20 15:15:42 - 0:00:00 - ============ Initialized logger ============
# INFO - 05/19/20 15:15:42 - 0:00:00 - accumulate_gradients: 1
#                                      ae_steps: [[], [], []]
#                                      amp: -1
#                                      asm: False
#                                      attention_dropout: 0.1
#                                      batch_size: 4
#                                      beam_size: 1
#                                      bptt: 256
#                                      bt_src_langs: []
#                                      bt_steps: [[], [], []]
#                                      clip_grad_norm: 5
#                                      clm_steps: [[], [], []]
#                                      command: python train.py --exp_name mlm_tlm_BafiaBuluEwondo --exp_id maml --dump_path './dumped/' --data_path 'data/processed' --lgs 'Bafia-Bulu|Bafia-MKPAMAN_AMVOE_Ewondo|Bulu-MKPAMAN_AMVOE_Ewondo' --clm_steps '' --mlm_steps 'Bafia,Bulu,Bafia-Bulu|Bafia,MKPAMAN_AMVOE_Ewondo,Bafia-MKPAMAN_AMVOE_Ewondo|Bulu,MKPAMAN_AMVOE_Ewondo,Bulu-MKPAMAN_AMVOE_Ewondo' --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout '0.1' --attention_dropout '0.1' --gelu_activation true --batch_size 4 --bptt 256 --optimizer 'adam,lr=0.0001' --epoch_size 6360 --max_epoch 100 --validation_metrics _valid_mlm_ppl --stopping_criterion '_valid_mlm_ppl,10' --eval_bleu false --remove_long_sentences_train True --remove_long_sentences_valid True --remove_long_sentences_test True --train_n_samples '-1' --valid_n_samples '-1' --test_n_samples '-1' --exp_id "maml"
#                                      context_size: 0
#                                      data_path: data/processed
#                                      debug: False
#                                      debug_slurm: False
#                                      debug_train: False
#                                      dropout: 0.1
#                                      dump_path: ./dumped/mlm_tlm_BafiaBuluEwondo/maml
#                                      early_stopping: False
#                                      emb_dim: 1024
#                                      encoder_only: True
#                                      epoch_size: 6360
#                                      eval_bleu: False
#                                      eval_only: False
#                                      exp_id: maml
#                                      exp_name: mlm_tlm_BafiaBuluEwondo
#                                      fp16: False
#                                      gelu_activation: True
#                                      global_rank: 0
#                                      group_by_size: True
#                                      id2lang: {0: 'Bulu', 1: 'MKPAMAN_AMVOE_Ewondo'}
#                                      is_master: True
#                                      is_slurm_job: False
#                                      lambda_ae: 1
#                                      lambda_bt: 1
#                                      lambda_clm: 1
#                                      lambda_mlm: 1
#                                      lambda_mt: 1
#                                      lambda_pc: 1
#                                      lang2id: {'Bulu': 0, 'MKPAMAN_AMVOE_Ewondo': 1}
#                                      langs: [['Bafia', 'Bulu'], ['Bafia', 'MKPAMAN_AMVOE_Ewondo'], ['Bulu', 'MKPAMAN_AMVOE_Ewondo']]
#                                      length_penalty: 1
#                                      lg_sampling_factor: -1
#                                      lgs: ['Bafia-Bulu', 'Bafia-MKPAMAN_AMVOE_Ewondo', 'Bulu-MKPAMAN_AMVOE_Ewondo']
#                                      local_rank: 0
#                                      master_port: -1
#                                      max_batch_size: 0
#                                      max_epoch: 100
#                                      max_len: 100
#                                      max_vocab: -1
#                                      meta_learning: True
#                                      meta_params: ...
#                                      min_count: 0
#                                      mlm_steps: [[('Bafia', None), ('Bulu', None), ('Bafia', 'Bulu')], [('Bafia', None), ('MKPAMAN_AMVOE_Ewondo', None), ('Bafia', 'MKPAMAN_AMVOE_Ewondo')], [('Bulu', None), ('MKPAMAN_AMVOE_Ewondo', None), ('Bulu', 'MKPAMAN_AMVOE_Ewondo')]]
#                                      mono_dataset: {'Bulu': {'train': 'data/processed/train.Bulu.pth', 'valid': 'data/processed/valid.Bulu.pth', 'test': 'data/processed/test.Bulu.pth'}, 'MKPAMAN_AMVOE_Ewondo': {'train': 'data/processed/train.MKPAMAN_AMVOE_Ewondo.pth', 'valid': 'data/processed/valid.MKPAMAN_AMVOE_Ewondo.pth', 'test': 'data/processed/test.MKPAMAN_AMVOE_Ewondo.pth'}}
#                                      mt_steps: [[], [], []]
#                                      multi_gpu: False
#                                      multi_node: False
#                                      n_gpu_per_node: 1
#                                      n_heads: 8
#                                      n_langs: 2
#                                      n_layers: 6
#                                      n_nodes: 1
#                                      n_samples: {'train': -1, 'valid': -1, 'test': -1}
#                                      n_task: 3
#                                      node_id: 0
#                                      optimizer: adam,lr=0.0001
#                                      para_dataset: {('Bulu', 'MKPAMAN_AMVOE_Ewondo'): {'train': ('data/processed/train.Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.pth', 'data/processed/train.Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.pth'), 'valid': ('data/processed/valid.Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.pth', 'data/processed/valid.Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.pth'), 'test': ('data/processed/test.Bulu-MKPAMAN_AMVOE_Ewondo.Bulu.pth', 'data/processed/test.Bulu-MKPAMAN_AMVOE_Ewondo.MKPAMAN_AMVOE_Ewondo.pth')}}
#                                      pc_steps: [[], [], []]
#                                      reload_checkpoint:
#                                      reload_emb:
#                                      reload_model:
#                                      remove_long_sentences: {'train': True, 'valid': True, 'test': True}
#                                      remove_long_sentences_test: True
#                                      remove_long_sentences_train: True
#                                      remove_long_sentences_valid: True
#                                      sample_alpha: 0
#                                      save_periodic: 0
#                                      share_inout_emb: True
#                                      sinusoidal_embeddings: False
#                                      split_data: False
#                                      stopping_criterion: _valid_mlm_ppl,10
#                                      test_n_samples: -1
#                                      tokens_per_batch: -1
#                                      train_n_samples: -1
#                                      use_lang_emb: True
#                                      use_memory: False
#                                      valid_n_samples: -1
#                                      validation_metrics: _valid_mlm_ppl
#                                      word_blank: 0
#                                      word_dropout: 0
#                                      word_keep: 0.1
#                                      word_mask: 0.8
#                                      word_mask_keep_rand: 0.8,0.1,0.1
#                                      word_pred: 0.15
#                                      word_rand: 0.1
#                                      word_shuffle: 0
#                                      world_size: 1
# INFO - 05/19/20 15:15:42 - 0:00:00 - The experiment will be stored in ./dumped/mlm_tlm_BafiaBuluEwondo/maml
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - Running command: python train.py --exp_name mlm_tlm_BafiaBuluEwondo --exp_id maml --dump_path './dumped/' --data_path 'data/processed' --lgs 'Bafia-Bulu|Bafia-MKPAMAN_AMVOE_Ewondo|Bulu-MKPAMAN_AMVOE_Ewondo' --clm_steps '' --mlm_steps 'Bafia,Bulu,Bafia-Bulu|Bafia,MKPAMAN_AMVOE_Ewondo,Bafia-MKPAMAN_AMVOE_Ewondo|Bulu,MKPAMAN_AMVOE_Ewondo,Bulu-MKPAMAN_AMVOE_Ewondo' --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout '0.1' --attention_dropout '0.1' --gelu_activation true --batch_size 4 --bptt 256 --optimizer 'adam,lr=0.0001' --epoch_size 6360 --max_epoch 100 --validation_metrics _valid_mlm_ppl --stopping_criterion '_valid_mlm_ppl,10' --eval_bleu false --remove_long_sentences_train True --remove_long_sentences_valid True --remove_long_sentences_test True --train_n_samples '-1' --valid_n_samples '-1' --test_n_samples '-1'
#
# WARNING - 05/19/20 15:15:42 - 0:00:00 - Signal handler installed.
# INFO - 05/19/20 15:15:42 - 0:00:00 - ============ langs: Bafia, Bulu
# INFO - 05/19/20 15:15:42 - 0:00:00 - ============ Monolingual data (Bafia)
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/train.Bafia.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 273575 words (18211 unique) in 6359 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/valid.Bafia.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 34423 words (18211 unique) in 794 sentences. 8 unknown words (8 unique) covering 0.02% of the data.
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/test.Bafia.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 34892 words (18211 unique) in 794 sentences. 5 unknown words (5 unique) covering 0.01% of the data.
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - ============ Monolingual data (Bulu)
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/train.Bulu.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 701924 words (18211 unique) in 23118 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/valid.Bulu.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 87801 words (18211 unique) in 2889 sentences. 30 unknown words (29 unique) covering 0.03% of the data.
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/test.Bulu.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 88173 words (18211 unique) in 2889 sentences. 31 unknown words (29 unique) covering 0.04% of the data.
#
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - ============ Parallel data (Bafia-Bulu)
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/train.Bafia-Bulu.Bafia.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 273575 words (18211 unique) in 6359 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/train.Bafia-Bulu.Bulu.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 180062 words (18211 unique) in 6359 sentences. 0 unknown words (0 unique) covering 0.00% of the data.
# INFO - 05/19/20 15:15:42 - 0:00:00 - Removed 0 empty sentences.
# INFO - 05/19/20 15:15:42 - 0:00:00 - Removed 0 empty sentences.
# INFO - 05/19/20 15:15:42 - 0:00:00 - Removed 34 too long sentences.
#
# INFO - 05/19/20 15:15:42 - 0:00:00 - Loading data from data/processed/valid.Bafia-Bulu.Bafia.pth ...
# INFO - 05/19/20 15:15:42 - 0:00:00 - 34423 words (18211 unique) in 794 sentences. 8 unknown words (8 unique) covering 0.02% of the data.
LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                        (attentions): ModuleList(
#                                          (0): MultiHeadAttention(
#                                            (q_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (k_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (v_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (out_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                          )
#                                          (1): MultiHeadAttention(
#                                            (q_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (k_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (v_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (out_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                          )
#                                          (2): MultiHeadAttention(
#                                            (q_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (k_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (v_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (out_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                          )
#                                          (3): MultiHeadAttention(
#                                            (q_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (k_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (v_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (out_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                          )
#                                          (4): MultiHeadAttention(
#                                            (q_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (k_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (v_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (out_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                          )
#                                          (5): MultiHeadAttention(
#                                            (q_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (k_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (v_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                            (out_lin): Linear(in_features=1024, out_features=1024, bias=True)
#                                          )
#                                        )
#                                        (layer_norm1): ModuleList(
#                                          (0): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (2): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (3): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (4): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (5): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                        )
#                                        (ffns): ModuleList(
#                                          (0): TransformerFFN(
#                                            (lin1): Linear(in_features=1024, out_features=4096, bias=True)
#                                            (lin2): Linear(in_features=4096, out_features=1024, bias=True)
#                                          )
#                                          (1): TransformerFFN(
#                                            (lin1): Linear(in_features=1024, out_features=4096, bias=True)
#                                            (lin2): Linear(in_features=4096, out_features=1024, bias=True)
#                                          )
#                                          (2): TransformerFFN(
#                                            (lin1): Linear(in_features=1024, out_features=4096, bias=True)
#                                            (lin2): Linear(in_features=4096, out_features=1024, bias=True)
#                                          )
#                                          (3): TransformerFFN(
#                                            (lin1): Linear(in_features=1024, out_features=4096, bias=True)
#                                            (lin2): Linear(in_features=4096, out_features=1024, bias=True)
#                                          )
#                                          (4): TransformerFFN(
#                                            (lin1): Linear(in_features=1024, out_features=4096, bias=True)
#                                            (lin2): Linear(in_features=4096, out_features=1024, bias=True)
#                                          )
#                                          (5): TransformerFFN(
#                                            (lin1): Linear(in_features=1024, out_features=4096, bias=True)
#                                            (lin2): Linear(in_features=4096, out_features=1024, bias=True)
#                                          )
#                                        )
#                                        (layer_norm2): ModuleList(
#                                          (0): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (1): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (2): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (3): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (4): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                          (5): LayerNorm((1024,), eps=1e-12, elementwise_affine=True)
#                                        )
#                                        (memories): ModuleDict()
#                                        (pred_layer): PredLayer(
#                                          (proj): Linear(in_features=1024, out_features=18211, bias=True)
#                                        )
#                                      )
# INFO - 05/19/20 15:15:44 - 0:00:03 - Number of parameters (model): 94772003
# INFO - 05/19/20 15:15:53 - 0:00:11 - Found 0 memories.
# INFO - 05/19/20 15:15:53 - 0:00:11 - Found 6 FFN.
# INFO - 05/19/20 15:15:53 - 0:00:11 - Found 102 parameters in model.
# INFO - 05/19/20 15:15:53 - 0:00:11 - Optimizers: model
# WARNING - 05/19/20 15:15:53 - 0:00:11 - Reloading checkpoint from ./dumped/mlm_tlm_BafiaBuluEwondo/maml/checkpoint.pth ...
# WARNING - 05/19/20 15:15:53 - 0:00:12 - Not reloading checkpoint optimizer model.
# WARNING - 05/19/20 15:15:53 - 0:00:12 - No 'num_updates' for optimizer model.
# WARNING - 05/19/20 15:15:53 - 0:00:12 - Checkpoint reloaded. Resuming at epoch 4 / iteration 2124 ...
# Exception 'para'
# INFO - 05/19/20 15:15:56 - 0:00:15 - ============ Starting epoch 4 ... ============
# INFO - 05/19/20 15:15:56 - 0:00:15 - Creating new training data iterator (pred,Bafia) ...

# %%
# save the result
#! rsync -av --progress /content/meta_XLM/XLM/dumped/mlm_tlm_BafiaBuluEwondo  /content/drive/"My Drive"/African_Translator/models/africa/cluster1
# Out:
# sending incremental file list
# mlm_tlm_BafiaBuluEwondo/
# mlm_tlm_BafiaBuluEwondo/maml/
# mlm_tlm_BafiaBuluEwondo/maml/best-valid_mlm_ppl.pth
#     379,907,028 100%   34.52MB/s    0:00:10 (xfr#1, to-chk=16/19)
# mlm_tlm_BafiaBuluEwondo/maml/checkpoint.pth
#   1,138,112,989 100%   32.05MB/s    0:00:33 (xfr#2, to-chk=15/19)
# mlm_tlm_BafiaBuluEwondo/maml/params.pkl
#           3,597 100%    8.69kB/s    0:00:00 (xfr#3, to-chk=14/19)
# mlm_tlm_BafiaBuluEwondo/maml/train.log
#         357,997 100%  704.85kB/s    0:00:00 (xfr#4, to-chk=13/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-Bulu.test.txt
#          90,637 100%  176.67kB/s    0:00:00 (xfr#5, to-chk=11/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-Bulu.valid.txt
#          90,425 100%  174.17kB/s    0:00:00 (xfr#6, to-chk=10/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-MKPAMAN_AMVOE_Ewondo.test.txt
#          78,600 100%  149.33kB/s    0:00:00 (xfr#7, to-chk=9/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bafia-MKPAMAN_AMVOE_Ewondo.valid.txt
#          79,452 100%  138.55kB/s    0:00:00 (xfr#8, to-chk=8/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-Bafia.test.txt
#         136,739 100%  233.04kB/s    0:00:00 (xfr#9, to-chk=7/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-Bafia.valid.txt
#         135,349 100%  219.93kB/s    0:00:00 (xfr#10, to-chk=6/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-MKPAMAN_AMVOE_Ewondo.test.txt
#          80,846 100%  130.71kB/s    0:00:00 (xfr#11, to-chk=5/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.Bulu-MKPAMAN_AMVOE_Ewondo.valid.txt
#          79,461 100%  122.20kB/s    0:00:00 (xfr#12, to-chk=4/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bafia.test.txt
#         134,447 100%  201.37kB/s    0:00:00 (xfr#13, to-chk=3/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bafia.valid.txt
#         136,106 100%  201.08kB/s    0:00:00 (xfr#14, to-chk=2/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bulu.test.txt
#          91,072 100%  134.14kB/s    0:00:00 (xfr#15, to-chk=1/19)
# mlm_tlm_BafiaBuluEwondo/maml/hypotheses/ref.MKPAMAN_AMVOE_Ewondo-Bulu.valid.txt
#          89,554 100%  130.53kB/s    0:00:00 (xfr#16, to-chk=0/19)
#
# sent 1,519,976,685 bytes  received 340 bytes  34,156,787.08 bytes/sec
# total size is 1,519,604,299  speedup is 1.00

# %% [markdown]
# **Train a (unsupervised/supervised) MT from a pretrained meta-model**

# %%
# %env epoch_size=6360
# %env lgs=Bafia-Bulu
# Out:
# env: epoch_size=6360
# env: lgs=Bafia-Bulu

# %%
# limit the number of examples (-1 by default for non limitation)
# %env train_n_samples=-1
# %env valid_n_samples=-1
# %env test_n_samples=-1
#--train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples

# %env eval_bleu=true
! chmod +x src/evaluation/multi-bleu.perl
# Out:
# env: train_n_samples=-1
# env: valid_n_samples=-1
# env: test_n_samples=-1
# env: eval_bleu=true

# %%
# %env stopping_criterion=valid_mt_bleu,10
# %env validation_metrics=valid_mt_bleu
# %env reload_model=dumped/mlm_tlm_BafiaBulu/maml/best-valid_mlm_ppl.pth,dumped/mlm_tlm_BafiaBulu/maml/best-valid_mlm_ppl.pth
# %env ae_steps=Bafia,Bulu
# %env bt_steps=Bafia-Bulu-Bafia,Bulu-Bafia-Bulu
# Out:
# env: stopping_criterion=valid_mt_bleu,10
# env: validation_metrics=valid_mt_bleu
# env: reload_model=dumped/mlm_tlm_BafiaBulu/maml/best-valid_mlm_ppl.pth,dumped/mlm_tlm_BafiaBulu/maml/best-valid_mlm_ppl.pth
# env: ae_steps=Bafia,Bulu
# env: bt_steps=Bafia-Bulu-Bafia,Bulu-Bafia-Bulu

# %%
# %env train_n_samples=-1
# %env valid_n_samples=-1
# %env test_n_samples=-1

# %env max_epoch=100

# unsupervised MT
! python train.py --exp_name UnSupMT_BafiaBulu --exp_id $exp_id --dump_path ./dumped/ --reload_model $reload_model --data_path $OUTPATH --lgs $lgs --ae_steps $ae_steps --bt_steps $bt_steps --word_shuffle 3 --word_dropout 0.1 --word_blank 0.1 --lambda_ae '0:1,100000:0.1,300000:0' --encoder_only false --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout 0.1 --attention_dropout 0.1 --gelu_activation true --tokens_per_batch 2000 --batch_size $batch_size --bptt 256 --optimizer adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001 --epoch_size $epoch_size --max_epoch $max_epoch --eval_bleu $eval_bleu --stopping_criterion $stopping_criterion --validation_metrics $validation_metrics --train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples --remove_long_sentences_train $remove_long_sentences_train --remove_long_sentences_valid $remove_long_sentences_valid --remove_long_sentences_test $remove_long_sentences_test

# %%
#! rsync -av --progress /content/meta_XLM/XLM/dumped/mlm_tlm_BafiaBulu  /content/drive/"My Drive"/African_Translator/models/africa/cluster1

# %%
# %env train_n_samples=-1
# %env valid_n_samples=-1
# %env test_n_samples=-1

# %env max_epoch=100
# %env batch_size=1
# supervised MT
# %env mt_steps=Bafia-Bulu,Bulu-Bafia          
! python train.py --exp_name MT_BafiaBulu --exp_id $exp_id  --dump_path ./dumped/ --reload_model $reload_model --data_path $OUTPATH --lgs $lgs --ae_steps $ae_steps --mt_steps $mt_steps --bt_steps $bt_steps --word_shuffle 3 --word_dropout 0.1 --word_blank 0.1 --lambda_ae '0:1,100000:0.1,300000:0' --encoder_only false --emb_dim 1024 --n_layers 6 --n_heads 8 --dropout 0.1 --attention_dropout 0.1 --gelu_activation true --tokens_per_batch 2000 --batch_size $batch_size --bptt 256 --optimizer adam_inverse_sqrt,beta1=0.9,beta2=0.98,lr=0.0001 --epoch_size $epoch_size --max_epoch $max_epoch --eval_bleu $eval_bleu --stopping_criterion $stopping_criterion --validation_metrics $validation_metrics --train_n_samples $train_n_samples --valid_n_samples $valid_n_samples --test_n_samples $test_n_samples --remove_long_sentences_train $remove_long_sentences_train --remove_long_sentences_valid $remove_long_sentences_valid --remove_long_sentences_test $remove_long_sentences_test

# %%
#! rsync -av --progress /content/meta_XLM/XLM/dumped/mlm_tlm_BafiaBulu  /content/drive/"My Drive"/African_Translator/models/africa/cluster1

# %%
d=[]
while(1):
  d.append(d)
